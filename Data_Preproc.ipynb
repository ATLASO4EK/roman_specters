# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
script_path = os.getcwd()
data_path = os.path.join(script_path, 'data')
path = os.path.join(data_path, 'control', 'mk1')

# %%
files = os.listdir(path)
file = os.path.join(path, files[0])

# %%
df = pd.read_csv(file, delim_whitespace=True)
# Out:
# C:\Users\atlas\AppData\Local\Temp\ipykernel_14592\2961836325.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True)

# %%
df
# Out:
#                   #X            #Y        #Wave    #Intensity
# 0       18910.985093  30496.069167  2002.417969  12803.853516
# 1       18910.985093  30496.069167  2001.458008  13013.024414
# 2       18910.985093  30496.069167  2000.498047  12979.162109
# 3       18910.985093  30496.069167  1999.538086  12984.517578
# 4       18910.985093  30496.069167  1998.577148  13076.103516
# ...              ...           ...          ...           ...
# 532870  18978.985093  30524.069167   931.446289   7742.299805
# 532871  18978.985093  30524.069167   930.273438   7607.999512
# 532872  18978.985093  30524.069167   929.100586   7460.912109
# 532873  18978.985093  30524.069167   927.927734   7547.125000
# 532874  18978.985093  30524.069167   926.754883   7682.508301
#
# [532875 rows x 4 columns]

# %%
df.iloc[:,2:4]
# Out:
#               #Wave    #Intensity
# 0       2002.417969  12803.853516
# 1       2001.458008  13013.024414
# 2       2000.498047  12979.162109
# 3       1999.538086  12984.517578
# 4       1998.577148  13076.103516
# ...             ...           ...
# 532870   931.446289   7742.299805
# 532871   930.273438   7607.999512
# 532872   929.100586   7460.912109
# 532873   927.927734   7547.125000
# 532874   926.754883   7682.508301
#
# [532875 rows x 2 columns]

# %%
x, y = df['#Wave'].tolist(), df['#Intensity'].tolist()

# %%
plt.plot(x, y)
